# %% [markdown]
# ---
# title: "TF-IDF"
# subtitle: "with a recap of material covered so far"
# author:
#   - name: Charles Pletcher
#     affiliations: Tufts University
#     orcid: 0000-0003-2734-5511
#     email: charles.pletcher@tufts.edu
# license:
#   code: MIT
# date: 2025-03-11
# ---
#
# ## TF-IDF - An Introduction
#
# Term Frequency — Inverse Document Frequency, or TF-IDF, is a powerful, if deceptively simple, way of determining keywords in a text. As its name suggests, it is comprised of two parts:
#
# ### Term Frequency (TF)
#
# The number of times that a term — typically, a token or a phrase — appears in a document. We can normalize this using various techniques. Generally speaking, we want to use the _relative_ frequency, or the raw frequency divided by the number of terms in the document.
#
# ### Document Frequency (DF)
#
# The number of documents in which a term appears. Again, there are common normalizations that we will typically perform, such as adding a small ε value to avoid dividing by zero.
#
# _Inverse_ document frequency, or IDF, is just the multiplicative inverse, or reciprocal, of DF.
#
# In practice, however, IDF is usually logarithmically scaled, i.e., $IDF=\log(n/DF)$ where $n$ is the number of documents in the corpus.
#
# ## Prefatory matters
#
# In order to get a sense of a basic implementation of TF-IDF, we first need some text to work with. To get some text, we'll need to review a few things about Python, and we'll need to learn how to use the `lxml` library to get text out of TEI XML files — the kinds of files that store much of the textual data and metadata that we use in digital humanities.
#
# ### Install `lxml`
#
# `%pip` (note the `%`) is a special command built into Jupyter notebooks that lets us use the Python package manager `pip`.
#
# To install a package, we just enter `%pip install` and then the package name in a code cell, like so:

# %%
# %pip install lxml
# Out:
# Collecting lxml
#   Downloading lxml-5.3.1-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (3.7 kB)
# Downloading lxml-5.3.1-cp312-cp312-manylinux_2_28_x86_64.whl (5.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 35.0 MB/s eta 0:00:00
# Installing collected packages: lxml
# Successfully installed lxml-5.3.1
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Import libraries
#
# With `lxml` installed, we now need to import the `etree` library, along with the `Path` constructor from the built-in `pathlib`.

# %%
from lxml import etree
from pathlib import Path

# %% [markdown]
# ### Initialize our path
#
# We'll use the `Path` constructor to grab the XML files that we need to parse:
#
# :::{tip}
# You can read more about **glob patterns** [here](https://code.visualstudio.com/docs/editor/glob-patterns).
# :::

# %%
files = Path("./xml/tlg0012").glob("**/*perseus-eng*.xml")

# %% [markdown]
# ### Set up namespaces for TEI parsing
#
# We also need to define a few namespaces to make it easier to find what we need in the XML files.

# %%
TEI_NS = "http://www.tei-c.org/ns/1.0"
XML_NS = "http://www.w3.org/XML/1998/namespace"

NAMESPACES = {
    "tei": TEI_NS,
    "xml": XML_NS,
}

# %% [markdown]
# ### Process the files
#
# Now we're ready to iterate through the files and extract the text.

# %%
for file in files:
    # print the name of the file as a sanity check
    print(file)
    
    # etree.parse() reads the file and turns the raw XML into an object that we can use in Python
    tree = etree.parse(file)

    # xpath() is a method that applies **xpath expressions** to search through the XML.
    # This xpath expression says, "Find any `tei:div` element with a `subtype` of `'card'`.
    # Under that element, get any text." The second argument, `namespaces=`, tells the
    # method to use the supplied namespaces as shortcuts, so we don't have to type out
    # "http://www.tei-c.org/ns/1.0" every time we want an element in the TEI namespace.

    text = tree.xpath(f"//tei:div[@subtype='card']//text()", namespaces=NAMESPACES)

    # xpath() returns an array of matches, so we initialize an empty array to store the
    # results. We could use a list comprehension, but for now rewriting these
    # lines as a list comprehension is left as an exercise for the reader.
    cleaned_text = []

    # Now we iterate through each string returned by `xpath()`
    for t in text:
        # `strip()` removes leading and trailing whitespace; if all that's left is an empty
        # string, we don't care about it.
        if t.strip() != "":
            cleaned_text.append(t.strip())

    # We make sure that we actually *have* text before writing just the text, without
    # TEI elements, to a separate file. No need to write an empty file, right?
    if len(cleaned_text) > 0:
        # A lot is happening here:
        #
        # 1. `str(file)` turns the `Path` object into a `str`
        # 2. `split("/")` splits the resulting string at every "/"
        # 3. `[-1]` takes the last element of the list returned by `split("/")`
        # 4. `replace(".xml", ".txt")` changes the extension of the file
        # 
        # So something like "xml/tlg0012/tlg001/tlg0012.tlg001.perseus-eng3.xml"
        # is transformed into "tlg0012.tlg001.perseus-eng3.txt".
        with open(str(file).split("/")[-1].replace(".xml", ".txt"), "w+") as f:
            # We write the text to the file, `join`-ing each element in
            # `cleaned_text` with a newline ("\n")
            f.write("\n".join(cleaned_text))

# %% [markdown]
# ## TF-IDF in Action
#
# Now that we have our text files, we can start implementing some basic TF-IDF analysis.
#
# First, let's tokenize our text. In the past, we have used `split()` and regular expressions to handle tokenization, but we need to start getting serious about handling punctuation. Let's use the Natural Language Toolkit, or NLTK, instead.
#
# ### Install the NLTK

# %%
# %pip install nltk
# Out:
# Collecting nltk
#   Downloading nltk-3.9.1-py3-none-any.whl.metadata (2.9 kB)
# Collecting click (from nltk)
#   Downloading click-8.1.8-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: joblib in /home/codespace/.local/lib/python3.12/site-packages (from nltk) (1.4.2)
# Collecting regex>=2021.8.3 (from nltk)
#   Downloading regex-2024.11.6-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (40 kB)
# Collecting tqdm (from nltk)
#   Downloading tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Downloading nltk-3.9.1-py3-none-any.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 24.0 MB/s eta 0:00:00
# Downloading regex-2024.11.6-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (796 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 796.9/796.9 kB 27.6 MB/s eta 0:00:00
# Downloading click-8.1.8-py3-none-any.whl (98 kB)
# Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
# Installing collected packages: tqdm, regex, click, nltk
# Successfully installed click-8.1.8 nltk-3.9.1 regex-2024.11.6 tqdm-4.67.1
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Download support files
#
# With the NLTK installed, we can now download the support files that it needs for tokenization.

# %%
import nltk

# download the files needed for tokenization
# the punkt tokenizer should be installed already,
# but let's download it just in case
nltk.download("punkt")
nltk.download("punkt_tab")
# Out:
# [nltk_data] Downloading package punkt to /home/codespace/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /home/codespace/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %% [markdown]
# ### Tokenize texts
#
# With the tokenizer downloaded, we can now read in and tokenize each text.

# %%
# Initialize the tokenizer
from nltk.tokenize import word_tokenize

# Initialize an empty dictionary to store the tokenized texts
tokenized_texts = {}

# Get a Path.glob() iterator for the .txt files that you've created in this directory.
# Can you figure out what the new `[1-4]` segment is doing?
text_files = Path(".").glob("tlg0012.tlg00*.perseus-eng[1-4].txt")

# Iterate through the text files, reading and tokenizing them one by one,
# then storing the list of tokens in our `tokenized_texts` dictionary —
# so we'll be getting a dictionary of lists.
for file in text_files:
    name = str(file)

    with open(file) as f:
        # Notice we're lowercasing the text. You don't *have*
        # to do this, but it helps eliminate some noise for
        # our purposes.
        text = f.read().lower()
        tokens = word_tokenize(text)

        # Let's just print the length of the tokens list to make
        # sure we're getting sane results. We'll use string interpolation
        # to identify which text we're working with.
        print(f"There are {len(tokens)} tokens in {name}.")

        # Store each file's `tokens` list in the `tokenized_texts`
        # dictionary, using the filename as the key.
        tokenized_texts[name] = tokens
# Out:
# There are 200630 tokens in tlg0012.tlg001.perseus-eng3.txt.
# There are 135463 tokens in tlg0012.tlg002.perseus-eng4.txt.
# There are 175611 tokens in tlg0012.tlg001.perseus-eng4.txt.
# There are 152631 tokens in tlg0012.tlg002.perseus-eng3.txt.

# %% [markdown]
# ### Count the tokens
#
# Now, we could count these tokens by hand, but why do that when Python gives us the `Counter` object?

# %%
from collections import Counter

# Using our `tokenized_texts` dictionary, we'll iterate
# through each key-value pair — remember, the keys are
# filenames and the values are lists of tokens.
# We'll get a count of the tokens by passing the list to
# `Counter`, then we'll change the value for that key to
# a dictionary with its own keys, `tokens` and `counts`.

for filename, tokens in tokenized_texts.items():
    counts = Counter(tokens)

    tokenized_texts[filename] = {"tokens": tokens, "counts": counts}

# %% [markdown]
# Now we can check to see what our frequencies look like.

# %%
tokenized_texts["tlg0012.tlg001.perseus-eng3.txt"]["counts"]["odysseus"]
# Out:
# 128

# %% [markdown]
# ### Calculate the document frequency for a given term
#
# Let's compare occurrences of the strings `"odysseus"` and `"achilles"` — we probably
# expect the former to "matter" more for the _Odysseus_, and the latter for the _Iliad_. Let's see if that's the case.

# %%
df_achilles = 0
df_odysseus = 0

# Calculate the DF for "odysseus" and "achilles".
# We iterate through the dictionary, and then simply
# count the number of files in which we find each term.
# For these two terms, we should probably expect DFs of 4.
for filename, values in tokenized_texts.items():
    if "odysseus" in values['counts']:
        df_odysseus += 1
    
    if "achilles" in values["counts"]:
        df_achilles += 1

# Now we'll import the log function to calculate the IDF for each term.
from math import log10

n_docs = len(tokenized_texts.keys())

idf_achilles = log10(n_docs / df_achilles)
idf_odysseus = log10(n_docs / df_odysseus)

print(idf_achilles)
# Out:
# 0.0

# %%
# Now let's calculate the TF-IDF "score" for each term in each document.

# Once again, iterate through the dictionary.
for filename, values in tokenized_texts.items():
    # Get the total number of terms in each file — we'll
    # use this to calculate the relative frequency as our
    # TF.
    total_terms = len(values['tokens'])

    # Get the TF for each term in this file.
    tf_achilles = values['counts']['achilles'] / total_terms
    tf_odysseus = values['counts']['odysseus'] / total_terms

    # Remember, the simplest version of TF-IDF is just
    # TF * 1/DF
    tf_idf_achilles = tf_achilles * idf_achilles
    tf_idf_odysseus = tf_odysseus * idf_odysseus

    # Now we can report on the statistics for this file
    print(f"""In {filename}:
TF of achilles: {tf_achilles}
TF of odysseus: {tf_odysseus}
TF-IDF of achilles: {tf_idf_achilles}
TF-IDF of odysseus: {tf_idf_odysseus}
""")
# Out:
# In tlg0012.tlg001.perseus-eng3.txt:
# TF of achilles: 0.002043562777251657
# TF of odysseus: 0.000637990330459054
# TF-IDF of achilles: 0.0
# TF-IDF of odysseus: 0.0
#
# In tlg0012.tlg002.perseus-eng4.txt:
# TF of achilles: 0.0001254955227626732
# TF of odysseus: 0.0042816119530794386
# TF-IDF of achilles: 0.0
# TF-IDF of odysseus: 0.0
#
# In tlg0012.tlg001.perseus-eng4.txt:
# TF of achilles: 0.002403038534032606
# TF of odysseus: 0.0007061061095261686
# TF-IDF of achilles: 0.0
# TF-IDF of odysseus: 0.0
#
# In tlg0012.tlg002.perseus-eng3.txt:
# TF of achilles: 0.0001048279838302835
# TF of odysseus: 0.0041603606082643765
# TF-IDF of achilles: 0.0
# TF-IDF of odysseus: 0.0

# %% [markdown]
# Well, the TF-IDF isn't super interesting, but at least we have the TF to fall back on.
#
# :::{note}
# Can you describe what happened? How might we solve this problem?
# :::

# %% [markdown]
# ### Overcoming frequent words
#
# In such a small corpus, it can be difficult to guess words that don't appear in all documents — certainly names of heroes like Achilles and Odysseus will appear in all of the documents, meaning $\log(n/DF)$ will always be 0.
#
# But we can use the `set()` constructor to find words that do not appear in all of the documents, and calculate TF-IDF on them.
#
# In programming, a **set** is very similar to a list, except it guarantees that it only contains at most 1 of every element.
#
# Let's start small:

# %%
my_list = [1, 1, 2, 3, 3]

set(my_list)
# Out:
# {1, 2, 3}

# %% [markdown]
# Notice how calling `set()` on `my_list` gets rid of the duplicate 1s and 3s. We can do likewise with strings.

# %%
non_universal_terms = {}

for filename, values in tokenized_texts.items():
    my_set = set(values['counts'].keys())

    for other_file, other_values in tokenized_texts.items():
        # make sure we don't compare the file
        # to itself, otherwise the difference
        # will be the empty set
        if other_file != filename:
            my_set -= set(other_values['counts'].keys())
    
    # now push the remaining set of terms to the dictionary
    non_universal_terms[filename] = my_set

# log `non_universal_terms` as a sanity check
non_universal_terms
# Out:
# {'tlg0012.tlg001.perseus-eng3.txt': {'break-down',
#   'cephisus',
#   'agrius',
#   'escapeth',
#   'exist',
#   'lyres',
#   'unwon',
#   'unabating',
#   'scantiest',
#   'leech',
#   'overturn',
#   'blood.',
#   'warreth',
#   'gffts',
#   'defender',
#   'rake',
#   'licymnius',
#   'ninth—so',
#   'teareth',
#   'afright',
#   'more—and',
#   'themuselves',
#   'ascania',
#   'gods—that',
#   'zeus—who',
#   'reprisal',
#   'possesseth',
#   'consorteth',
#   'movedst',
#   'heptaporus',
#   'handmaiden',
#   'ensigns',
#   'euphorbus',
#   'breathing-space',
#   'mellay',
#   'upbare',
#   'vexing',
#   'sore-wearied',
#   'orphan',
#   'thrice-prayed-for',
#   'eudorus',
#   'mountainside',
#   'astypylus',
#   'safer',
#   '423.3',
#   'surpasseth',
#   'broidering',
#   'them—aias',
#   'inclineth',
#   'scantier',
#   'piaited',
#   'thereof—nay',
#   'heareth',
#   'horse-men',
#   'caenus',
#   'chicks',
#   'victors',
#   'declaredst',
#   'oresbius',
#   'dallied',
#   'talaus',
#   'boagrius',
#   'vouchsafeth',
#   'therefrom—to',
#   'regardeth',
#   'unfought',
#   'coroneia',
#   'fresh-wounded',
#   'entreating',
#   'hah',
#   'rageth',
#   'showest',
#   'honses',
#   'coppersmiths',
#   '—then',
#   'taslet',
#   'delights',
#   'side-traces',
#   'cruelty',
#   'orithyia',
#   'astynous',
#   'smitings',
#   'nooks',
#   'annointed',
#   'undaunted—cast',
#   'thalysius',
#   'journeying',
#   'waggons',
#   'feareth',
#   'workest',
#   'puffing',
#   'ilean',
#   'separates',
#   'ships—fools',
#   'strifes',
#   'marriage-bed',
#   'hips',
#   'howl',
#   'presseth',
#   'agamemon',
#   'all-unscathed',
#   'chaplets',
#   'swearing',
#   'aglaïa',
#   'conceiveth',
#   'swift-streaming',
#   'scourgeth',
#   'teil',
#   'hindereth',
#   'hunger-pangs',
#   'strophius',
#   'epicles',
#   'marshallers',
#   'fervent',
#   'dastard',
#   'hyades',
#   'peiros',
#   'aesyetes',
#   'yesternight',
#   'alalcomenean',
#   'earth—',
#   '47.1',
#   'stymphalus',
#   'darest',
#   'urgest',
#   'defacement',
#   'ill-favoured',
#   'constellations',
#   'parthenius',
#   'aepy',
#   'nurtureth',
#   'hand—an',
#   'iapetus',
#   'are—yet',
#   'plough—then',
#   'outrun',
#   'amphigeneia',
#   'rendeth',
#   'blackened',
#   'prothoënor',
#   'gown',
#   'bestirring',
#   'loathsome',
#   'pylaeus',
#   'strongly-wrought',
#   'maemalus',
#   'looketh',
#   'fatal',
#   'resound',
#   'loiter',
#   'unfed',
#   'nesaea',
#   'ill-boding',
#   'heraldship',
#   'fencing',
#   '399.1',
#   'best—to',
#   'byre',
#   'shrinketh',
#   'left—',
#   'pheidippus',
#   'thymbre',
#   'feebly',
#   'wetteth',
#   'verge',
#   'kerchief',
#   'simoeisius',
#   'fearsome',
#   'axius—axius',
#   'agave',
#   'incomplete',
#   'relax',
#   'pylaemenes',
#   'setteth',
#   'meagre',
#   'contrariwise',
#   'caletor',
#   'liveth',
#   'astyalus',
#   'thereover',
#   'attiring',
#   'war-god',
#   'walketh',
#   'proclamation',
#   'approveth',
#   'avow',
#   'amphinone',
#   'pike',
#   'down—lest',
#   'assault',
#   'through—',
#   'araisodarus',
#   'shrieked',
#   'pointless',
#   'threatenings',
#   'came—',
#   'sullying',
#   'billowy',
#   'gleaming-bright',
#   'giveth',
#   'centre-piece',
#   '379.1',
#   'heaven—a',
#   'suborned',
#   'ariseth',
#   'first-born',
#   'home-going',
#   'staking',
#   'pheme',
#   'aleian',
#   '49.1',
#   'glideth',
#   'dog-fly',
#   'ephyri',
#   'cleobulus',
#   'serves',
#   'well-twisted',
#   'hed',
#   'evippus',
#   'polyaemon',
#   'broodeth',
#   'waggon-track',
#   'pried',
#   'winnower',
#   'shield-rim',
#   'shield-men',
#   'axle-trees',
#   'turning-point',
#   'alcathous',
#   'aethices',
#   'maeonians',
#   'asteropaeus',
#   'sore-bested',
#   'methiinks',
#   'melteth',
#   'aud',
#   'prothoön',
#   'profitless',
#   'many—my',
#   'antheia',
#   'cherishes',
#   'lesser',
#   'weigheth',
#   'charis',
#   'over-powering',
#   'shriek',
#   '519.1',
#   'damans',
#   'denieth',
#   '177.1',
#   'clonius',
#   'discern',
#   'eateth',
#   'haemon',
#   'pursue—even',
#   'lameness',
#   'belloweth',
#   'portioned',
#   'elders—to',
#   'mailed',
#   'rift',
#   'gates—',
#   'recketh',
#   'crowned—the',
#   'echeclus',
#   'this—a',
#   'sweepeth',
#   'gifs',
#   'hand-maids',
#   'unpaid',
#   '499.1',
#   'satnius',
#   'neeks',
#   'entereth',
#   'shrinking',
#   'hippolochus',
#   '—whereas',
#   'measuring',
#   'kinfolk',
#   'valiantly',
#   'send—even',
#   '—if',
#   '261.1',
#   'oenomaus',
#   'come—sore',
#   'rosettes',
#   'ponderest',
#   'bronze-wrought',
#   'things—my',
#   'swiftness',
#   'gyrtius',
#   'bearers',
#   'curbing',
#   'prophetic',
#   'alpheius',
#   'cringed',
#   'tenderly',
#   'careth',
#   'thelr',
#   'antiphonus',
#   '181.1',
#   'boebeïs',
#   'aepeia',
#   'aegaeon',
#   'enquirest',
#   'wordrous',
#   'wind-swept',
#   'crusheth',
#   'rhigmus',
#   'immovably',
#   'pyraechmes',
#   'daysman',
#   'renegade',
#   'rending',
#   'swooned',
#   'deathward',
#   'aide',
#   'phlegyes',
#   'arrogant',
#   'well-inhabited',
#   'thing—to',
#   'availeth',
#   'zeus—hard',
#   'weepest',
#   'getteth',
#   'ophianassa',
#   'lyctus—for',
#   '319.1',
#   'firm-fixed',
#   'wot',
#   '557.1',
#   'neighed',
#   '13.2',
#   'grievously',
#   'hither-ward',
#   'pleadings',
#   'witlessness',
#   'him—and',
#   'earth—the',
#   'scolus',
#   'thiat',
#   'adornment',
#   'twang',
#   'war-din',
#   'on—it',
#   'dodonaean',
#   'pealed',
#   'vineland',
#   'afore-time',
#   'tilth',
#   'strife—will',
#   'plain—even',
#   'ungirt',
#   'sminthian',
#   'rain-drops',
#   'corslet',
#   'departeth',
#   'fair-woven',
#   'aided',
#   '43.1',
#   'unpossessed',
#   'vehement',
#   'thalpius',
#   'seemeth',
#   'forgettest',
#   'myrine',
#   'rods',
#   'panthous',
#   'wandereth',
#   'uttermost',
#   'dwelleth',
#   'shimmering',
#   'halter',
#   'ascanius',
#   'violet-hued',
#   'thymbraeus',
#   '53.2',
#   'swallows',
#   'over-weening',
#   'separated',
#   'mingleth',
#   'drave',
#   'shearing',
#   'flighty',
#   'appeasement',
#   '521.1',
#   'intervene',
#   'marsh-land',
#   'vapour',
#   'be-neath',
#   'toiling',
#   'racked',
#   'warped',
#   'cadmeians',
#   'biddeth',
#   'helicaon',
#   'wolf-born',
#   'lamentest',
#   '—no',
#   'constraint',
#   'plaintively',
#   'leucus',
#   'hand-clasps',
#   'honour',
#   'driveth',
#   'iphinous',
#   '159.1',
#   '51.1',
#   'afar—fool',
#   'oozeth',
#   'weareth',
#   'clave',
#   'swft',
#   'ceasest',
#   'nethermost',
#   'her—fair',
#   'phocians',
#   'twittered',
#   'vaguely',
#   'unransomed',
#   'breaketh',
#   'affright',
#   'couching-places',
#   'runagate',
#   '569.1',
#   'cicalas',
#   'dint',
#   'deïcoön',
#   'trusteth',
#   'fair-ankled',
#   'idaean',
#   'sakes',
#   'bestirreth',
#   'undermost',
#   'wide-scattered',
#   'clan',
#   'circleth',
#   'ships—would',
#   'river—and',
#   'joinings',
#   'whenso',
#   'scattereth',
#   'changeth',
#   'insults',
#   'skirts',
#   'hopeth',
#   'cilicia',
#   'cheiron',
#   'go—it',
#   'thrusteth',
#   'crier',
#   'grovelled',
#   'jewels',
#   'eneti',
#   'sinketh',
#   'breast-straps',
#   'weaving-rod',
#   'pereia',
#   'him—for',
#   'swiftfooted',
#   'araphius',
#   'oak-tree',
#   'wist',
#   'hippothous',
#   'shay',
#   'entreatment',
#   'autonous',
#   'freshly-watered',
#   'diveth',
#   'boys—a',
#   'leaguer',
#   'company.',
#   'constrained',
#   'smiteth',
#   'herds-men',
#   'gat',
#   'flax',
#   'tartarus',
#   'deemest',
#   'ensnareth',
#   'rhadamanthys',
#   'aiders',
#   'feathered',
#   'glancing',
#   'enjoined',
#   'vanquisheth',
#   'advance',
#   'cheating',
#   '—all',
#   'heart—it',
#   'ones—even',
#   'delighting',
#   'beauteously',
#   'muse—best',
#   'swift-glancing',
#   'ruinous',
#   'causeth',
#   'soul-devouring',
#   'covereth',
#   'hippodamus',
#   '—hampered',
#   'coiled',
#   "'twere",
#   'isander',
#   'refreshing',
#   'life—even',
#   'callianassa',
#   'counselled',
#   'harvesttime',
#   'great-souled',
#   'gazeth',
#   'wrathful',
#   'sideward',
#   'sore-pressed',
#   'food—',
#   'pheneos',
#   'upbringing',
#   '395.1',
#   'copreus',
#   'zeleia',
#   'sword—for',
#   'thrasius',
#   'destroyeth',
#   'underbrush',
#   "'why",
#   'heard—',
#   'exultest',
#   'sand—until',
#   'apportion',
#   'slaving',
#   'measurehess',
#   'unheard',
#   'assaileth',
#   'phaenops',
#   'eilithyiae',
#   'marshalling',
#   'echinae',
#   'soles',
#   'enfolding',
#   'nurseth',
#   'harbour',
#   'war—both',
#   'bane—to',
#   'frontlets',
#   'birth-place',
#   'scorned',
#   'eileithyiae',
#   'willeth',
#   'thoë',
#   'iaera',
#   'madest',
#   'bearable',
#   'made—three',
#   'eëtion',
#   'offerest',
#   'eteocles',
#   'fillies',
#   'scandeia',
#   'men-at-arms',
#   'caeneus',
#   'turmuoil',
#   'lapith',
#   'tract',
#   'grovelling',
#   'marveling',
#   '315.1',
#   'sitteth',
#   'fir-tree',
#   'gaped',
#   'asaeus',
#   'maiden—youth',
#   'confounded',
#   'hector—for',
#   'them—the',
#   '—would',
#   'decayeth',
#   'deemeth',
#   'beseemeth',
#   'earth—who',
#   'lieth',
#   '81.1',
#   'livedst',
#   'graving',
#   'liest',
#   'flutter',
#   'discerned',
#   'well-balanced',
#   'fulfilleth',
#   'mountain-tops',
#   'carts',
#   'selli',
#   '311.1',
#   'themselves—even',
#   'archeptolemus',
#   'fordone',
#   'pillage',
#   'coursed',
#   'antilochos',
#   'cleareth',
#   'pastureland',
#   'wayfaring',
#   'dancing-floor',
#   '565.2',
#   'gasped',
#   'augur—these',
#   'nipples',
#   'endlessly',
#   'sharp-toothed',
#   'unbearable',
#   'borus',
#   'thick-flying',
#   'timolus',
#   'apollos',
#   'halteth',
#   'high-gated',
#   '483.2',
#   'elm',
#   'thwarter',
#   'frieads',
#   'darteth',
#   'stripligs',
#   'chalcon',
#   'baldrics—',
#   'striketh',
#   'hades—even',
#   'swing',
#   'biding',
#   'muscle',
#   'pastured',
#   'wise-hearted',
#   'horse-man',
#   'gods—he',
#   'suiting',
#   'long-barbed',
#   'sullen',
#   'aegis—the',
#   'studs',
#   'alcathous—son',
#   '—one',
#   'sipylus',
#   'judgements',
#   'medesicaste',
#   'unshaken',
#   'hyllus',
#   'surest',
#   'aether',
#   'suffereth',
#   'cunningly-wrought',
#   'habitation',
#   'stroking',
#   'gathereth',
#   '565.1',
#   'child-bearing',
#   'drawest',
#   'overweeningly',
#   'caucones',
#   'feasteth',
#   'pales',
#   'guest-friends',
#   'taut',
#   'running—meanwhile',
#   'ear-rings',
#   'hitherward',
#   "'twixt",
#   'channel—',
#   'laodice',
#   'evil-minded',
#   'asian',
#   'ialysus',
#   '275.1',
#   'prothous',
#   '551.1',
#   'mantineia',
#   'isus',
#   'lycophron',
#   'vauntingly',
#   'them—even',
#   'blacker',
#   'dip',
#   'slime',
#   'labourers',
#   'skulk',
#   'rhodians',
#   'pedasus',
#   'lengthy',
#   'penning',
#   'lysander',
#   'fallow-land',
#   'whem',
#   'melanippus',
#   'summoning',
#   'bodv',
#   'better—to',
#   'varied',
#   'lily-like',
#   'drink-offiering',
#   'prayed—to',
#   'bright-tressed',
#   'hurtling',
#   'home-return',
#   'adrastus',
#   'open-mouthed',
#   'out-stretched',
#   'bethougnt',
#   'poureth',
#   'granicus',
#   'turning-points',
#   'floateth',
#   'no—for',
#   'threshing-floors',
#   'achelous',
#   'guideth',
#   'devisers',
#   'pliant',
#   'unbought',
#   'onsets',
#   'forging',
#   'hurleth',
#   'supposed',
#   'unsacked',
#   'adjuring',
#   'fluently',
#   'discerneth',
#   'fleshing-block',
#   'turningpost',
#   'capys',
#   'sea—even',
#   'fair-founded',
#   'error',
#   'necklaces',
#   'profiteth',
#   '33.1',
#   'assenting',
#   'ennomus',
#   'renounced',
#   'reviler',
#   'echecles',
#   'scyrus',
#   'ploughers',
#   "soe'er",
#   'macar',
#   'tempest-blast',
#   'ranging',
#   'sharp-fanged',
#   'outstay',
#   '121.1',
#   'revereth',
#   'heedeth',
#   'selleïs',
#   'marreth',
#   'thick-hidden',
#   'orthaeus',
#   'sufficeth',
#   'honourable',
#   'doryclus',
#   'sthenelaus',
#   'chouds',
#   'it—yet',
#   'holdest',
#   'forbare',
#   'overmastering',
#   'stripes',
#   'echius',
#   'peace—yet',
#   'cutteth',
#   'wool-comber',
#   'prancing',
#   'epistrophus',
#   'marking',
#   '329.1',
#   'fighteth',
#   'embankments',
#   'stoodest',
#   'quenching',
#   'thaleia',
#   'streaming',
#   'accomplisheth',
#   'steading—but',
#   'devour—far',
#   'mill-stone',
#   'harry',
#   'numbed',
#   'haze',
#   'oft',
#   "whatsoe'er",
#   'softer',
#   'euphemus',
#   'watcheth',
#   'them—these',
#   'horses—even',
#   'thrasymelus',
#   'man—fool',
#   'abundantly—',
#   'spear-thrusts',
#   'waggon',
#   'man-hood',
#   'plummet',
#   'resteth',
#   'water-snake',
#   '—nay',
#   'immortals-',
#   'displeasing',
#   'unspeakable—wolves',
#   'streams—the',
#   'rusheth',
#   'draggeth',
#   '551.2',
#   'bell-wether',
#   'box-wood',
#   'enwrapping',
#   'consolation',
#   'eïoneus',
#   'bendeth',
#   'polymelus',
#   'swoopeth',
#   'panteth',
#   'euneos',
#   'brandisheth',
#   'flieth',
#   'worketh',
#   '37.1',
#   'vehemence',
#   'lamentings',
#   'farm-stead',
#   'wantonly',
#   'meseemeth',
#   'agacles',
#   'cymothoë',
#   'mightier—',
#   'rhodius',
#   'zeus-nurtured',
#   'mount—yet',
#   '229.1',
#   'swift-flowing',
#   '—himself',
#   'mayhap',
#   'endureth',
#   'beateth',
#   'shallow',
#   'tilleth',
#   "whoe'er",
#   'turneth',
#   'tangle',
#   'amidst',
#   'settest',
#   'rhipe',
#   'achaeams',
#   'chideth',
#   'stout-hooved',
#   'showeth',
#   'all-ensnaring',
#   'streweth',
#   'bronze-harnessed',
#   'taskmaster',
#   'flashing-helm',
#   'leïtus',
#   'dawned',
#   'forsakest',
#   'be.and',
#   "ne'er",
#   'gave—even',
#   'taiaemenes',
#   'evenus',
#   'speio',
#   'exuiting',
#   'thiem',
#   'ormenius',
#   'deviseth',
#   'rainbow',
#   'moveless',
#   'joyeth',
#   'way—in',
#   'son—his',
#   'slumberest',
#   'infallible',
#   'mountain-dwelling',
#   'outthrew',
#   'forgat',
#   'meed',
#   'trustv',
#   'deïochus',
#   'moat',
#   'lasheth',
#   'formeth',
#   'amphiclus',
#   'ialmenus',
#   'dust-cloud',
#   'staineth',
#   'riseth',
#   'trustest',
#   'finst',
#   'whomever',
#   'lycastus',
#   'harnesses',
#   'spear-cast',
#   'stinging',
#   'asclepius',
#   'amphius',
#   'gnaw',
#   'better—',
#   'calleth',
#   'achdeans',
#   'biting',
#   'hyrtius',
#   'due—',
#   'standeth',
#   'loud-lowing',
#   'me—that',
#   'unprofitable',
#   "where'er",
#   'thundereth',
#   'forearm',
#   'helenus',
#   'bronze-mailed',
#   'tear-fraught',
#   '409.1',
#   'heed—',
#   'maim',
#   'lyrnessus',
#   'clytomedes',
#   'whirleth',
#   'cymindis',
#   'pleasure—the',
#   'thick-set',
#   'speedeth',
#   'overmastered',
#   'cadmeians—',
#   'amny',
#   'acamas',
#   'far-shadowing',
#   'exadius',
#   'townsfolk—far',
#   'claims',
#   'loud-bellowing',
#   'mustered',
#   '271.1',
#   'flanks',
#   'sputtering',
#   'honoureth',
#   'overpowering',
#   'dishonoured',
#   'peered',
#   'hopest',
#   'noëmon',
#   'arousing',
#   'straight-flying',
#   '11.1',
#   'crasheth',
#   'storm-footed',
#   'podarces',
#   'murmuring',
#   'lighteneth',
#   "bull's-hides",
#   'colour',
#   'sheep-fold',
#   'arrogance',
#   'capaneus',
#   'ill-sounding',
#   'more—of',
#   'halië',
#   'pallor',
#   'palaces',
#   'dressing',
#   'bright-eyed',
#   'thersilochus',
#   'plain—being',
#   'telamon—fools',
#   'agreement',
#   'hypeirochus',
#   'echo',
#   'stealing',
#   'prized',
#   'budeum',
#   'achaeans—',
#   'polyneices',
#   'bronze-clad',
#   'loth',
#   'lodged',
#   'say—yet',
#   'soundeth',
#   'pen',
#   'reed',
#   'gargarus',
#   'slinketh',
#   'knight',
#   'more.',
#   'trickling',
#   'strengthless',
#   'pinnets',
#   'there—for',
#   'polypoetes',
#   'encloseth',
#   'warcry',
#   'froma',
#   'axius—',
#   'castianeira',
#   'therethrough',
#   'swifted-footed',
#   'above—',
#   'creaked',
#   ...},
#  'tlg0012.tlg002.perseus-eng4.txt': {'squaring',
#   'uncivil',
#   'phronios',
#   'credit',
#   'surf-beaten',
#   'absence.',
#   'mixing-jugs',
#   'suck',
#   'adding',
#   'poison',
#   'puzzling',
#   'unsettling',
#   'coasts',
#   'eurymedousa',
#   'charming',
#   'ogygian.',
#   'frame',
#   'formerly',
#   'annoyed',
#   'freemen',
#   'aft',
#   'tatters',
#   'citizens',
#   'pits',
#   'scarred',
#   'lively',
#   'handing',
#   'movingly',
#   'rankle',
#   'lean-to',
#   'alkippe',
#   'swinging',
#   'adventures',
#   'calamities',
#   'fact',
#   'weakened',
#   'purchased',
#   'phaidimos',
#   'injury',
#   'sea-',
#   'deign',
#   'saluting',
#   'persistent',
#   'thunderbolts',
#   'plausible',
#   'inches',
#   'phemios',
#   'shadiest',
#   'wonders',
#   'stories',
#   'warmly',
#   'commend',
#   'fire-seed',
#   'exactly',
#   'kindly-natured',
#   'beauties',
#   'thoroughly',
#   'lessons',
#   'impunity',
#   'venerable',
#   'group',
#   'dirty',
#   'melanthios',
#   'noised',
#   'expectations',
#   'smart-looking',
#   'elysium',
#   'bachelors',
#   'perilous',
#   'admired',
#   'wrecks',
#   'fret',
#   'drowned',
#   'long-suffering',
#   'foreboded',
#   'beechmast',
#   'disloyal',
#   'reminds',
#   'scepter-bearing',
#   'expectation',
#   'sleeves',
#   'patron',
#   'ogre',
#   'connected',
#   'shoals',
#   'gambol',
#   'dairy',
#   'grunted',
#   'bags',
#   'bruises',
#   'caring',
#   'admittance',
#   'bubbled',
#   'howling',
#   'persist',
#   'alkinoos',
#   'seagulls',
#   'atrociously',
#   'humbly',
#   'disrespectful',
#   'boring',
#   'eteocretans',
#   'unfastened',
#   'incorrigible',
#   'wonderfully',
#   'difficulties',
#   'rangers',
#   'frugal',
#   'euphrosunê',
#   'conceivable',
#   'anybody',
#   'solitude',
#   'scarf',
#   'walled',
#   'shockingly',
#   'principles',
#   'foreland',
#   'hoggets',
#   'neaira',
#   'swaying',
#   'warned',
#   'skimmed',
#   'costs',
#   'singular',
#   'unwarily',
#   'son-in-law.',
#   'sweetmeats',
#   'resuming',
#   'crime',
#   'valuable',
#   'merchants',
#   'overboard',
#   'limbo',
#   'vantage',
#   'difference',
#   'steaming',
#   'rekindle',
#   'insignificant',
#   'tempts',
#   'acre',
#   'crossbeams',
#   'resemble',
#   'loveliness',
#   'abetting',
#   'swooning',
#   'chickens',
#   'grassed',
#   'land-locked',
#   'thesprotian',
#   'bloodlessly',
#   'kerdea',
#   'recognizing',
#   'peering',
#   'platform',
#   'consulted',
#   'inspiration',
#   'misconduct',
#   'cruse',
#   'talisman',
#   'arnaios',
#   'behave',
#   'estimation',
#   'antlered',
#   'cross-piece',
#   'affect',
#   'upholds',
#   'cairn',
#   'apt',
#   'musically',
#   'sicels',
#   'rude',
#   'govern',
#   'drown',
#   'alternatives',
#   'oikleus',
#   'unwaked',
#   'klymenos',
#   'starved',
#   'seduced',
#   'continent',
#   'allows',
#   'withholds',
#   'true-begotten',
#   'jelly',
#   'certify',
#   'hoeing',
#   'gut',
#   'adorn',
#   'ill-treat',
#   'breezy',
#   'scenes',
#   'religious',
#   'stratios',
#   'respectable',
#   'studied',
#   'cargoes',
#   'capturing',
#   'fish-like',
#   'entranced',
#   'wreckage',
#   'fleas',
#   'bearing-post',
#   'disguising',
#   'practice',
#   'afternoon',
#   'insisted',
#   'shocked',
#   'groove',
#   'interest',
#   'tapestry',
#   'bondsman',
#   'offense',
#   'pretense',
#   'market',
#   'tidily',
#   'townspeople',
#   'gracefulness',
#   'excuse',
#   'cleanses',
#   'massacre',
#   'fisherman',
#   'abounds',
#   'ungrafted',
#   'compel',
#   'thunder-bolts',
#   'offices',
#   'cooking',
#   'succeeded',
#   'stronghold',
#   'astonishment',
#   'prodigies',
#   'knock',
#   'scrubbed',
#   'providence',
#   'steersmen',
#   'trap',
#   'people-',
#   'drifted',
#   'gold-enthroned',
#   'nightfall',
#   'gardener',
#   'mid-ocean',
#   'unmeasurable',
#   'visitor',
#   'reprimand',
#   'landing',
#   'echetos',
#   'salutes',
#   'overflowing',
#   'boil',
#   'glide',
#   'clapped',
#   'reality',
#   'yells',
#   'hired',
#   'threes',
#   'object',
#   'striven',
#   'swill',
#   'position',
#   'seal',
#   'drubbing',
#   'cattle-lifting',
#   'geraistos',
#   'familiarity',
#   'unharnessed',
#   'emptied',
#   'maidservant',
#   'hazardous',
#   'peacefulness',
#   'grievance',
#   'unfold',
#   'freighting',
#   'blighting',
#   'languages',
#   'serious',
#   'injure',
#   'trees.',
#   'belief',
#   'legacy',
#   'racecourses',
#   'thistledown',
#   'identity',
#   'drain',
#   'youngster',
#   'polite',
#   'matrimony',
#   'bucket',
#   'waking',
#   'good-for-nothing',
#   'dinner-party',
#   'belong',
#   'antinoos',
#   'chimneys',
#   'ill-treating',
#   'sailor',
#   'rapt',
#   'gaia',
#   'shoveled',
#   'topes',
#   'world.',
#   'overflow',
#   'solitary',
#   'unpropitious',
#   'resembling',
#   'interesting',
#   'positive',
#   'cloisters.',
#   'handsome',
#   'privately',
#   'dawdle',
#   'chooses',
#   'villainy',
#   'damage',
#   'antiklos',
#   'kneading',
#   'spends',
#   'importunate',
#   'bitterest',
#   'tramps',
#   'contribute',
#   'funeral.',
#   'replenishing',
#   'twenty-oared',
#   'warful',
#   'bait',
#   'precincts',
#   'daytime',
#   'increasing',
#   'grandmother',
#   'funny',
#   'upstairs',
#   'strainers',
#   'conscience-stricken',
#   'many-sided',
#   'gossips',
#   'ekhthroi',
#   'butchering',
#   'detest',
#   'sea-king',
#   'downstairs',
#   'flavor',
#   'pins',
#   'swaggering',
#   'likes',
#   'recline',
#   'well-tilled',
#   'smelling',
#   'volunteers',
#   'shoo',
#   'carelessly',
#   'tidy',
#   'exterminate',
#   'obliged',
#   'import',
#   'guilds',
#   'eumaios',
#   'sidonia',
#   'abundance.',
#   'claws',
#   'demoptolemos',
#   'occurred',
#   'patience',
#   'dresses',
#   'center-post',
#   'pigsties',
#   'interests',
#   'freeze',
#   'poorer',
#   'acquaintance',
#   'female',
#   'hooting',
#   'scandalous',
#   'clamored',
#   'precipices',
#   'ash-wood',
#   'enlisting',
#   'adored',
#   'iros',
#   'cloisters',
#   'leukas',
#   'scoundrel',
#   'resume',
#   'erembians',
#   'floats',
#   'mesaulios',
#   'unrighteously',
#   'propitiation',
#   'firstly',
#   'overhear',
#   'ointments',
#   'anti-',
#   'rejoined',
#   'heralded',
#   'diplomacy',
#   'kreon',
#   'portended',
#   'refitting',
#   'revelers',
#   'clever',
#   'exiles',
#   'attempt',
#   'exhausted',
#   'voyage.',
#   'snap',
#   'dresser',
#   'salutations',
#   'absolutely',
#   'chamois',
#   'amount',
#   'parties',
#   'soften',
#   'scolded',
#   'briskly',
#   'required',
#   'quantities',
#   'pious',
#   'motioned',
#   'furthering',
#   'aglow',
#   'parts.',
#   'munch',
#   'doubling',
#   'sacrificial',
#   'illustrious',
#   'bribes',
#   'vassal',
#   'coherent',
#   'resins',
#   'appearance',
#   'repair',
#   'allow',
#   'banish',
#   'convene',
#   'vested',
#   'cheerfulness',
#   'blue',
#   'clouts',
#   'grill',
#   'ones.',
#   'result',
#   'anticipates',
#   'shifty',
#   'importunity',
#   'encouragingly',
#   'miller-woman',
#   'handy',
#   'dances',
#   'scolding',
#   'gossiping',
#   'ismaros',
#   'extremely',
#   'victuals',
#   'gatekeeper',
#   'he-goats',
#   'reasonably',
#   'drunkenness',
#   'damp',
#   'detain',
#   'damaged',
#   'boethoos',
#   'impossible',
#   'blotted',
#   'gourmet',
#   'customs',
#   'tracks',
#   'forge',
#   'ducts',
#   'severe',
#   'athletes',
#   'secured',
#   'muzzled',
#   'falsehood',
#   'site',
#   'tallied',
#   'leukothea',
#   'soot',
#   'sickening',
#   'services',
#   'nericum',
#   'prowls',
#   'succeeding',
#   'recalling',
#   'intended',
#   'halosydne',
#   'wayfarers',
#   'plucks',
#   'drenching',
#   'fishy',
#   'sheathe',
#   'drugged',
#   'fortune-telling',
#   'avenging',
#   'aietes',
#   'glutton',
#   'eurylokhos',
#   'messmates.',
#   'reminding',
#   'listens',
#   'telepylos',
#   'fine-looking',
#   'extra',
#   'water-loving',
#   'noses',
#   'ensconced',
#   'henchmen',
#   'outraged',
#   'stranded',
#   'ktesios',
#   'frisking',
#   'supporters',
#   'differently',
#   'krataiis',
#   'ghost',
#   'visitors',
#   'seldom',
#   'behaving',
#   'toys',
#   'evenings',
#   'anyhow',
#   'grease',
#   'manure',
#   'sundown',
#   'feckless',
#   'partner',
#   'recommend',
#   'merchandise',
#   'terror-struck',
#   'enabled',
#   'despairingly',
#   'vainest',
#   'deserve',
#   'strong-box',
#   'competitors',
#   'reflected',
#   'banishes',
#   'iphikles',
#   'akroneos',
#   'cretan',
#   'wretchedly',
#   'merchant',
#   'torture',
#   'unrecorded',
#   'twelvemonth',
#   'tambour',
#   'yours.',
#   'risked',
#   'torch-light',
#   'apartment',
#   'spell-proof',
#   'distinguished',
#   'comfortingly',
#   'thrifty',
#   'cleaning',
#   'goodness',
#   'lamentably',
#   'safest',
#   'expedition',
#   'shipwreck',
#   'apology',
#   'rascal',
#   'capable',
#   'beck',
#   'board.',
#   'eurymos',
#   'amphinomos',
#   'blessedness',
#   'usually',
#   'misconducted',
#   'excellently',
#   'genuine',
#   'apeira',
#   'intrigue',
#   'naturally',
#   'magician',
#   'worries',
#   'briefly',
#   'gobbets',
#   'fraud',
#   'suggestion',
#   'apatê',
#   'growl',
#   'competitions',
#   'jumpers',
#   'simpletons',
#   'intending',
#   'instinctive',
#   'cheese-racks',
#   'pacified',
#   'pig',
#   'prospered',
#   'disfigure',
#   'entirely',
#   'toll',
#   'carvers',
#   'hussies',
#   'drowning',
#   'oak-shoots',
#   'picking',
#   'overlap',
#   'cheeringly',
#   'horrified',
#   'thrinacian',
#   'intercourse',
#   'modest',
#   'pyriphlegethon',
#   'reckon',
#   'sounion',
#   'sea-horses',
#   'introduce',
#   'unbound',
#   'foreigner',
#   'glowing',
#   'style',
#   'dangerously',
#   'require',
#   'ripped',
#   'steadying',
#   'misbehaved',
#   'tricky',
#   'cechalian-',
#   'akastos',
#   'travelers',
#   'believes',
#   'intolerably',
#   'inches.',
#   'subtlety',
#   'situation',
#   'regained',
#   'impudent',
#   'selected',
#   'lump',
#   'trill',
#   'raiding',
#   'intends',
#   'house-keeper',
#   'questioning',
#   'thrives',
#   'gossamer',
#   'powerfully',
#   'mimicked',
#   'case-hardened',
#   'complaints',
#   'magnificently',
#   'fingered',
#   'phaethousa',
#   'reeking',
#   'miller-women',
#   'well-disposed',
#   'bleared',
#   'daughters-in-law',
#   'intention',
#   'rapids',
#   'to.',
#   'mountaintops',
#   'despairing',
#   'syra',
#   'excellency',
#   'sheathed',
#   'goddess.',
#   'soared',
#   'conferred',
#   'perjurer',
#   'acceptance',
#   'alkandra',
#   '=',
#   'verbal',
#   'jumping',
#   'invent',
#   'grafted',
#   'blank',
#   'lucky',
#   'simply',
#   'personal',
#   'high-handedly',
#   'wink',
#   'purely',
#   'fort',
#   'ringleaders',
#   'decently',
#   'dispute',
#   'aigyptos',
#   'bluster',
#   'hindering',
#   'ox-thong',
#   'packing',
#   'displayed',
#   'snaring',
#   'rigorously',
#   'banqueting-room',
#   'faint-hearted',
#   'continuing',
#   'sandal',
#   'riverhood',
#   'shambles',
#   'bully',
#   'noticing',
#   'proceeded',
#   'liberty',
#   'scampered',
#   'demodokos',
#   'epikaste',
#   'nêpenthes',
#   'overheard',
#   'athlêtês',
#   'nervous',
#   'accompaniment',
#   'periklymenos',
#   'atmosphere',
#   'squat',
#   'overarching',
#   'magnificent',
#   'stools',
#   'octopus',
#   'philoitios',
#   'dare-devil',
#   'aimlessly.',
#   'nimblest',
#   'dearth',
#   'answering',
#   'envelop',
#   'accounting',
#   'beckoned',
#   'well-found',
#   'lamos',
#   'ikarios',
#   'prison',
#   'luxury',
#   'raven',
#   'series',
#   'honestly',
#   'competing',
#   'compose',
#   'swindler',
#   'tyndarus',
#   'indisputable',
#   'relations',
#   'invites',
#   'nudged',
#   'boarhounds',
#   'ogygian',
#   'expression',
#   'drip',
#   'surrounding',
#   'squeal',
#   'luxuriantly',
#   'ravages',
#   'free-booters',
#   'gilding',
#   'ill-natured',
#   'pottering',
#   'square',
#   'kisses',
#   'bedside',
#   'meetings',
#   'leveled',
#   'interceded',
#   'liquor',
#   'messenians',
#   'barbarous',
#   'detested',
#   'infamy',
#   'timely',
#   'dreamed',
#   'discreditable',
#   'dikaios',
#   'shoes',
#   'cases',
#   'chance.',
#   'fatigue',
#   'heaven-sent',
#   'miscreants',
#   'scrolls',
#   'foothold',
#   'protects',
#   'melancholy',
#   'noiselessly',
#   'eurynomos',
#   'enriches',
#   'kindnesses',
#   'accurately',
#   'psyra',
#   'diverted',
#   'dears',
#   'limp',
#   'cypress-wood',
#   'enforce',
#   'mantios',
#   'complexion',
#   'twenty-four',
#   'lives.',
#   'second-rate',
#   'inheritance',
#   'endeavors',
#   'vivid',
#   'raisins',
#   'abusing',
#   'proofs',
#   'aurora',
#   'impress',
#   'petition',
#   'shuttles',
#   'gobbled',
#   'outshine',
#   'anchors',
#   'enmity',
#   'frightful',
#   'powder',
#   'bondwoman',
#   'stratagem',
#   'netted',
#   'fits',
#   'deafening',
#   'ikmalios',
#   'bliss',
#   'subtler',
#   'bevy',
#   'pigs-',
#   'dragon',
#   'egging',
#   'brush-wood',
#   'aver',
#   'wooden',
#   'continual',
#   'disgracefully',
#   'perfidy',
#   'stagger',
#   'bedded',
#   'minyan',
#   'crew.',
#   'water-sprinkling',
#   'preach',
#   'puzzled',
#   'visits',
#   'disturbance',
#   'crowning',
#   'krînô',
#   'muttering',
#   'deaths',
#   'becalmed',
#   'fifty-two',
#   'seriously',
#   'gloomy',
#   'convinced',
#   'starve',
#   'un-cared',
#   'sighs',
#   'interpretation',
#   'lowering',
#   'discuss',
#   'prevaricate',
#   'depends',
#   'mistrust',
#   'disturbed',
#   'screams',
#   'traveler',
#   'insist',
#   'dining',
#   'belonged',
#   'bolder',
#   'customary',
#   'courting',
#   'rills',
#   'good-naturedly',
#   'sympathy',
#   'foretold',
#   'tamed',
#   'removing',
#   'outbuildings',
#   'colors',
#   'charring',
#   'ultimately',
#   'nausithoos',
#   'furnished',
#   'schemes',
#   'amassed',
#   'pigsty',
#   'earshot',
#   'abominably',
#   'astounded',
#   'ceiling',
#   'dish',
#   'disparaging',
#   'neighboring',
#   'jeer',
#   'embellishments',
#   'tubs',
#   'grounds',
#   'juicy',
#   'ramping',
#   'beggarly',
#   'lent',
#   '-lay',
#   'uncertainty',
#   'tricks',
#   'haunted',
#   'widely',
#   'once.',
#   'freights',
#   'exploits',
#   'secure',
#   'lifts',
#   'yelps',
#   'jumped',
#   'naughtiness',
#   'menial',
#   'hearers',
#   'turned.',
#   'mysterious',
#   'abominable',
#   'impulse',
#   'baggage',
#   'eclipse',
#   'principal',
#   'hereditary',
#   'relation',
#   'amply',
#   'enchant',
#   'undergoing',
#   'oldest',
#   'cobwebs',
#   'antikleia',
#   'supersede',
#   'extraordinarily',
#   'enthroned',
#   'itylos',
#   'pounced',
#   'management',
#   'country-farm',
#   'coverings',
#   'ache',
#   'expected',
#   'unsuspicious',
#   'maron',
#   'uncivilized',
#   'frustrate',
#   'disrespectfully',
#   'giggling',
#   'carding',
#   'exit',
#   'shabby-looking',
#   'expounded',
#   'bed-prop',
#   'inch',
#   'close-in',
#   'plotted',
#   'lookers-on',
#   'fiber',
#   'considerable',
#   '-but',
#   'recoup',
#   'breadbaskets',
#   'flagging',
#   'eurykleia',
#   'uneaten',
#   'goatskins',
#   'grandfather',
#   'fuel',
#   'man-servant',
#   'staid',
#   'spending',
#   'persecuted',
#   'amphiaraos',
#   'fuller-handed',
#   'elect',
#   'disgust',
#   'poets',
#   'quality',
#   'instinct',
#   'backstay',
#   'gadding',
#   'agreeable',
#   'squalid',
#   'temesa',
#   'fretting',
#   'continues',
#   'butchered',
#   'antagonist',
#   'sided',
#   'usual',
#   'subscriptions',
#   'remove',
#   'contemptuously',
#   'descendants',
#   'meadowsweet',
#   'coated',
#   'withholding',
#   'prevails',
#   'disrespect',
#   'liberal',
#   'visibly',
#   'virgin',
#   'transgress',
#   'everyone',
#   'sights',
#   'reclined',
#   'feather',
#   'lookers',
#   'relieved',
#   'dolios',
#   ...},
#  'tlg0012.tlg001.perseus-eng4.txt': {'flours',
#   'bate',
#   'sources',
#   'axes-',
#   'wagon-road',
#   'parthenios',
#   'chirrup',
#   'talaimenes',
#   'earth-encircler',
#   'robs',
#   'sighed',
#   'unrighteous',
#   'out-distance',
#   'fastens',
#   'roost',
#   'pergamos',
#   'idaios',
#   'sages',
#   'diaphragm',
#   'thymbraios',
#   'twilight',
#   'establishing',
#   'rattle',
#   'feature',
#   'dale',
#   'espying',
#   'starting-post',
#   'assarakos',
#   'aigialeia',
#   'lowed',
#   'boons',
#   'laps',
#   'befriends',
#   'euenos',
#   'soaks',
#   'echeklos',
#   'serrated',
#   'cleaver',
#   'molos',
#   'tough-shielded',
#   'gatherer',
#   'otos',
#   'reflecting',
#   'movement',
#   'cataract',
#   'spiteful',
#   'dejected',
#   'severity',
#   'incite',
#   'deep-meadowed',
#   'crystal',
#   'pattering',
#   'carried-',
#   'talaos',
#   'unawarded',
#   'marshaler',
#   'mated',
#   'challenger',
#   'polyaimon',
#   'curbed',
#   'sthenelos',
#   'phalanx',
#   'likymnios',
#   'laughingly',
#   'aipytos',
#   'responsibility',
#   'desperate',
#   'branching',
#   'sthenelaos',
#   'paeonian',
#   'courteous',
#   'kaletor',
#   'raided',
#   'approval',
#   'effaced',
#   'swoops',
#   'euippos',
#   'pheidippos',
#   'spearsmen',
#   'showers',
#   'untied',
#   'selloi',
#   'strophios',
#   'defenders',
#   'resplendent',
#   'ill-pleased',
#   'swarms',
#   'ray',
#   'sepulcher',
#   'triumphant',
#   'amaze',
#   'victual',
#   'thenceforth',
#   'frightening',
#   'klea',
#   'visor',
#   'victor',
#   'ratify',
#   'phoceans',
#   'fountainhead',
#   'soar',
#   'butts',
#   'cooped',
#   'chattel',
#   'examine',
#   'languish',
#   'woolly',
#   'wines',
#   'time-',
#   'gloat',
#   'dropping',
#   'earnings',
#   'artificers',
#   'career',
#   'boisterous',
#   'hard-pressed',
#   'disobeys',
#   'admetos',
#   'succor',
#   'demoukhos',
#   'ignoble',
#   'unworthy',
#   'meekly',
#   'smarted',
#   'neighing',
#   'koön',
#   'knit',
#   'tumbling',
#   'leukos',
#   'cajoling',
#   'halcyon',
#   'ranked',
#   'mountains-',
#   'conciliate',
#   'keenly',
#   'tusked',
#   'homesteads',
#   'rendering',
#   'areilykos',
#   'dingle',
#   'forcing',
#   'epistrophos',
#   'eeriboia',
#   'eteokles',
#   'triple-barbed',
#   'lyrnessos',
#   'severs',
#   'unwashed',
#   'gray-bearded',
#   'brothers-in-law-for',
#   'transgressed',
#   'cleaves',
#   'titaresios',
#   'rancor',
#   'decline',
#   'eussoros',
#   'fleeter',
#   'dion',
#   'chances',
#   'rinsed',
#   'hyrtios',
#   'quoit',
#   'vesture',
#   'delivers',
#   'well-nigh',
#   'infatuated',
#   'fares',
#   'betide',
#   'aktaia',
#   'harmed',
#   'rhigmos',
#   'lads',
#   'untaken',
#   'stable-yard',
#   'cross-bar',
#   'varne',
#   'orcus',
#   'quits',
#   'upheld',
#   'balearic',
#   'daunt',
#   'mid-stream',
#   'thickens',
#   'stated',
#   'head-dress',
#   'arsinoos',
#   'devours',
#   'gush',
#   'undaunted',
#   'shouldered',
#   'thrasios',
#   'accident',
#   'thigh-bones',
#   'corruption',
#   'snags',
#   'robbing',
#   'plaiting',
#   'indifferent',
#   'deadened',
#   'coronea',
#   'hippothoos',
#   'overreach',
#   'deiochus',
#   'anew',
#   'charges',
#   'inveigle',
#   'overshadow',
#   'tow',
#   'stalked',
#   'thebaios',
#   'harness-mules',
#   'leopardess',
#   'said-',
#   'recoiled',
#   'railer',
#   'fresh-burnished',
#   'asklepios',
#   'sweet-singing',
#   'entrapping',
#   'pyraikhmes',
#   'egged',
#   'slobbered',
#   'fittest',
#   'bygones',
#   'demokoön',
#   'unplundered',
#   'bas',
#   'clarion',
#   'plays',
#   'particular',
#   'bronze-cheeked',
#   'migrated',
#   'swarmed',
#   'money',
#   'oinomaos',
#   'boyish',
#   'hyads',
#   'uncertain',
#   'overleap',
#   'gold-bedizened',
#   'camp-fires',
#   'alêthea',
#   'house-dogs',
#   'rival',
#   'couples',
#   'stickle',
#   'dock',
#   'winnowing-shovel',
#   'profess',
#   'pain-killing',
#   'kapaneus',
#   'disaffection',
#   'mansions',
#   'well-bolted',
#   'allowance',
#   'aesopos',
#   'wealthiest',
#   'dawning',
#   'opposed',
#   'baning',
#   'lights',
#   'reside',
#   'expound',
#   'bowstrings',
#   'nerved',
#   'asteropaios',
#   'minyas',
#   'judging',
#   'plenitude',
#   'rabble',
#   'linus-song',
#   'ormenos',
#   'prattling',
#   'divination',
#   'universe',
#   'onchestos',
#   'unwelcome',
#   'waiting-women',
#   'hundred-head',
#   'breathing-time',
#   'kreion',
#   'coast-land',
#   'acropolis',
#   'impetuously',
#   'unbelted',
#   'buds',
#   'truce',
#   'unloosed',
#   'deipyros',
#   'carelessness',
#   'sulking',
#   'pedaios',
#   'grateful',
#   'lykastos',
#   'overthrown',
#   'therefore-and',
#   'phlegyans',
#   'concourse',
#   'befitting',
#   'bronzed',
#   'drakios',
#   'wrong-doer',
#   'aphthitos',
#   'blamed',
#   'dikes',
#   'keener',
#   'disconcerted',
#   'cowed',
#   'amphigenea',
#   'lost-',
#   'kymodoke',
#   'arm-rods',
#   'divides',
#   'consulting',
#   'monger',
#   'unsteady',
#   'gainsaid',
#   'curdles',
#   'sister-in-law',
#   'crack',
#   'euphemos',
#   'pervaded',
#   'chaff-',
#   'marshaled',
#   'arbitrator',
#   'shamefacedness',
#   'serene',
#   'bronze-floored',
#   'lysandros',
#   'ajaxes',
#   'brutally',
#   'almighty',
#   'ekhepolos',
#   'mown',
#   'danae',
#   'garlands',
#   'mother-in-law',
#   'telos',
#   'autophonos',
#   'harmlessly',
#   'presuming',
#   'erebos',
#   'accord-',
#   'buckles',
#   'helenos',
#   'sulkily',
#   'carpathus',
#   'civil',
#   'warden',
#   'downwards',
#   'facing-bothways',
#   'bronze-smiths',
#   'smashing',
#   'headgear',
#   'wine-cup',
#   'foot-soldiers',
#   'texture',
#   'winning-post',
#   'narrowly',
#   'self-reliance',
#   'all-counseling',
#   'unsay',
#   'harping',
#   'myrtle-blossoms',
#   'odios',
#   'thunderer',
#   'overtakes',
#   'halizoni',
#   'deikoön',
#   'kymothoe',
#   'polyneikes',
#   'contain',
#   'lapis',
#   'klytomedes',
#   'thersilokhos',
#   'player',
#   'gnawed',
#   'inflict',
#   'overhead',
#   'hecuba',
#   'oiled',
#   'mountain-track',
#   'kephissos',
#   'upshot',
#   'shifting',
#   'width',
#   'dispatched',
#   'forbidden',
#   'boukolos',
#   'justly',
#   'beleaguering',
#   'manfulness',
#   'bode',
#   'plated',
#   'peneus',
#   'continents',
#   'adrastos',
#   'meonian',
#   'chanting',
#   'conversant',
#   'amisodoros',
#   'agastrophos',
#   'axios',
#   'gurgling',
#   'ennomos',
#   'openmouthed',
#   'metes',
#   'lather',
#   'full-flowing',
#   'waster',
#   'actual',
#   'straining',
#   'calmer',
#   'self-confidence.',
#   'haughtiness',
#   'designs',
#   'lykaon',
#   'mountain-spur',
#   'warriors-',
#   'lure',
#   'nibbling',
#   'hooked',
#   'pledges',
#   'stable-men',
#   'bruise',
#   'penalties',
#   'runaway',
#   'babel',
#   'limnorea',
#   'kebriones',
#   'preeminence',
#   'dells',
#   'cross-bars',
#   'undefended',
#   'needy',
#   'veering',
#   'kissês',
#   'cyprian',
#   'universal',
#   'give-and-take',
#   'scud',
#   'five-year-old',
#   'attire',
#   'gale-',
#   'northward',
#   'fellow-warriors',
#   'dries',
#   'death-throes',
#   'reassure',
#   'task-master',
#   'marshaling',
#   'physicians',
#   'seniority',
#   'invade',
#   'reassured',
#   'moira',
#   'histôr',
#   'hyrtakos',
#   'additional',
#   'seven-foot',
#   'peirar',
#   'furnace',
#   'goat-herd',
#   'renew',
#   'ill-disposed',
#   'forbids',
#   'tempers',
#   'dardanos',
#   'yarded',
#   'disinclined',
#   'midea',
#   'picks',
#   'titular',
#   'sodden',
#   'wreaked',
#   'partnership',
#   'assailants',
#   'collar-bones',
#   'frankincense',
#   'sternness',
#   'sticking',
#   'lavished',
#   'rejoices',
#   'mete',
#   'evil-hearted',
#   'unsoiled',
#   'isandros',
#   'metal',
#   'preside',
#   'recruits',
#   'destitute',
#   'broach',
#   'behead',
#   'kreontes',
#   'retire',
#   'offend',
#   'engaged',
#   'askalaphos',
#   'suffused',
#   'crocylea',
#   'twisting',
#   'prophesyings',
#   'valorously',
#   'jump',
#   'spade',
#   'surpassing',
#   'inclines',
#   'ame',
#   'poises',
#   'interrupt',
#   'encircling',
#   'patroness',
#   'moldy',
#   'trumpets',
#   'horrors',
#   'incarnate',
#   'tasseled',
#   'helike',
#   'hip-joint',
#   'phradmon',
#   'simoeisios',
#   'laodike',
#   'sinful',
#   'punishing',
#   'kastianeira',
#   'uprooting',
#   'indiscretion',
#   'drowsy',
#   'arkheptolemos',
#   'spreads',
#   'heats',
#   'churl',
#   'resent',
#   'roses',
#   'plumed',
#   'risk',
#   'fainthearted',
#   'thrash',
#   'assist',
#   'accusing',
#   'caressing',
#   'therapôn',
#   'irritated',
#   '-gates',
#   'strengthened',
#   'nerve',
#   'awarded',
#   'beleaguered',
#   'suing',
#   'outdid',
#   'herd-heifer',
#   'pell-mell',
#   'inexorable',
#   'coils',
#   'mines',
#   'hundred-handed',
#   'boldest',
#   'remounted',
#   'augeae',
#   'trickster',
#   'onslaught',
#   'vestments',
#   'disallow',
#   'instruction',
#   'panoply',
#   'false-tongued',
#   'pheneus',
#   'maniac',
#   'singled',
#   'gallops',
#   'towns',
#   'astypylos',
#   'flockmaster',
#   'philotês',
#   'file',
#   'stopping',
#   'alision',
#   'dupe',
#   'beaming',
#   'vindictive',
#   'daimones',
#   'aithra',
#   'woodmen',
#   'masonry',
#   'coarse',
#   'bodes',
#   'theraponte',
#   'implacable',
#   'somber',
#   'thessalos',
#   'indulge',
#   'pull',
#   'atymnios',
#   'orthaios',
#   'unheeded',
#   'iaira',
#   'single-edged',
#   'hang-dog',
#   'liar',
#   'parch',
#   'demands',
#   'tips',
#   'weapon',
#   'well-assured',
#   'alkimos',
#   'inciting',
#   'wielding',
#   'humans',
#   'unmolested',
#   'noisome',
#   'bryseae',
#   'pall',
#   'gravest',
#   'tartaros',
#   'struggles',
#   'showered',
#   'rescue',
#   'intervals',
#   'foray',
#   'instructed',
#   'plunder',
#   'parleying',
#   'stinted',
#   'welkin',
#   'competition',
#   'far-darting',
#   'hits',
#   'commune',
#   'purchase',
#   'argument',
#   'vault',
#   'intentions',
#   'ephyroi',
#   'exceeded',
#   'empire',
#   'remorseless',
#   'twixt',
#   'chiron',
#   'kicks',
#   'concerned',
#   'kaineus',
#   'suffuse',
#   'crushes',
#   'lopped',
#   'boils',
#   'scandea',
#   'glories',
#   'woodsman',
#   'akheloos',
#   'many-valleyed',
#   'opposing',
#   'tlepolemos',
#   'propitiating',
#   'teuthranos',
#   'whisks',
#   'forage',
#   'proficient',
#   'hippokoön',
#   'chariot-racing',
#   'augeas',
#   'pouncing',
#   'spercheios',
#   'exadios',
#   'counseling',
#   'middlemost',
#   'precise',
#   'preceding',
#   'silver-eddying',
#   'tries',
#   'reconciles',
#   'all-seeing',
#   'welfare',
#   'ill-favored',
#   'razed',
#   'dissuaded',
#   'trozen',
#   'draft',
#   'fastest',
#   'familiar',
#   'sesamus',
#   'emblems',
#   'implanted',
#   'unnoticed',
#   'overall',
#   'hangs',
#   'sprout',
#   'hammering',
#   'bud',
#   'alkandros',
#   'train',
#   'truer',
#   'exultant',
#   'passionately',
#   'cattle-raiding',
#   'ankaios',
#   'pandokos',
#   'fascinating',
#   'pitting',
#   'penetrated',
#   'deipylos',
#   'clamoring',
#   'mêtis',
#   'themselves-',
#   'javelin-match',
#   'forgets',
#   'reject',
#   'elm-tree',
#   'shuts',
#   'ankle-clasps',
#   'buoy',
#   'noontide',
#   'schooled',
#   'minister',
#   'labor-',
#   'obeying',
#   'banes',
#   'selleis',
#   'unnerved',
#   'thunder-cloud',
#   'akamas',
#   'chafe',
#   'extent',
#   'maimalos',
#   'erichthonios',
#   'enjoyment',
#   'courtesy',
#   'yokestraps',
#   'detailed',
#   'severely',
#   'heedfully',
#   'sift',
#   'tease',
#   'deepened',
#   'ceos',
#   'sokos',
#   'laogonos',
#   'endow',
#   'overjoyed',
#   'boudeion',
#   'myrmidon',
#   'graia',
#   'hounded',
#   'right-hand',
#   'laerkes',
#   'lykophron',
#   'melting',
#   'trechos',
#   'continuous',
#   'fastness',
#   'thalysios',
#   'lobes',
#   'alkimedon',
#   'convulsed',
#   'amphiklos',
#   'leadership',
#   'antiphonos',
#   'one-half',
#   'showering',
#   'khalkon',
#   'menaced',
#   'bullock-skins',
#   'arcades',
#   'dweller',
#   'finality',
#   'you-and',
#   'xanthos',
#   'rock-perched',
#   'needed',
#   'eye-brows',
#   'stew',
#   'chopping-block',
#   'peaceably',
#   'aipy',
#   'three-legged',
#   'ialmenos',
#   'pylaios',
#   'richly-equipped',
#   'impart',
#   'sunbeams',
#   'turtledoves',
#   'mid-air',
#   'aithe',
#   'pining',
#   'oath-offerings',
#   'sixthly',
#   'keladon',
#   'halizonoi',
#   'lament-making',
#   'heptaporos',
#   'kardamyle',
#   'saffron',
#   'imbrios',
#   'damming',
#   'praktios',
#   'protecting',
#   'greaved',
#   'hektor.',
#   'gold-bestudded',
#   'fight-',
#   'mantinea',
#   'slaughtering',
#   'haimon',
#   'saying-',
#   'laborers',
#   'meonia',
#   'jeopardy',
#   'foolishness',
#   'pylaimenes',
#   'diviner',
#   'hippomakhos',
#   'cuirass',
#   'matrons',
#   'polydoros',
#   'hussy',
#   'oratory',
#   'rhodios',
#   'distribute',
#   'apparel',
#   'bowstring',
#   'ill-fed',
#   'pillows',
#   'lysians',
#   'angle',
#   'hypeirochos',
#   'storming',
#   'restore',
#   'opportunely',
#   'preference',
#   'asios',
#   'sedition',
#   'hedged',
#   '-and',
#   'stichios',
#   'lykon',
#   'sharply',
#   'impregnable',
#   'wild-fowl',
#   'fatigued',
#   'exhort',
#   'sea-monster',
#   'serving-woman',
#   'sharpest',
#   'fixity',
#   'bedchambers',
#   'somehow',
#   'zelea',
#   'ineffable',
#   'foiling',
#   'imploringly',
#   'lykophontes',
#   'arkesilaos',
#   'simoeis',
#   'hipponoos',
#   'awards',
#   'rush-grown',
#   'sheepyards',
#   'salvation',
#   'envoys',
#   'mercilessly',
#   'aisyetes',
#   'spearsman',
#   'whistle',
#   'klonios',
#   'lookout',
#   'forfeit',
#   'swerving',
#   'extremity',
#   'fore-arm',
#   'perea',
#   'daitor',
#   'porridge',
#   'weather-beaten',
#   'visored',
#   'moaned',
#   'specially',
#   'sôphrôn',
#   'alight',
#   'buffeting',
#   'trice',
#   'cicadas',
#   'shirked',
#   'ship-building',
#   'she-wolves',
#   'ugliest',
#   'householder',
#   'askanios',
#   'avert',
#   'arkhelokhos',
#   'perkote',
#   'delivery',
#   'incur',
#   'leaps',
#   'persisted',
#   'contradicts',
#   'pronoos',
#   'backbone',
#   'center',
#   'gamboling',
#   'alektryon',
#   'hustled',
#   'pheras',
#   'battle-axe',
#   'harass',
#   'far-darter',
#   'kalkhas',
#   'disdaining',
#   'shrouds',
#   'wildfire',
#   'pranks',
#   'preferred',
#   'hacked',
#   'hand-to-hand',
#   'stabled',
#   'alkmaon',
#   'orb',
#   'effecting',
#   'hard-hearted',
#   'spouting',
#   'amphoteros',
#   'calmed',
#   'thunderstorm',
#   'zeus-descended',
#   'eionae',
#   'monument',
#   'violation',
#   'oppress',
#   'tuft',
#   'dangling',
#   'mykalessos',
#   'pine-trees',
#   'unpracticed',
#   'hippodamos',
#   'licyon',
#   'dives',
#   'engulf',
#   'schoinos',
#   'cozen',
#   'ascend',
#   'resembled',
#   'blood-',
#   'bellow',
#   'left-hand',
#   'untrue',
#   'olene',
#   'mixes',
#   'akessamenos',
#   'cramped',
#   'overpower',
#   'sea-fight',
#   'ormenios',
#   'pine-tree',
#   'foursquare',
#   'helikaon',
#   'wide-watered',
#   'blindly',
#   'fork',
#   'storm-tossed',
#   'foments',
#   'filly',
#   'dales',
#   'anemorea',
#   'heaven-born',
#   'quailing',
#   'fixing',
#   'ikarian',
#   'surnamed',
#   'ear-handled',
#   'highlands',
#   'baned',
#   'halo',
#   'deiopites',
#   'tricked',
#   'mid-battle',
#   'sallies',
#   'ferret-skin',
#   'aristos',
#   'telea',
#   'arriving',
#   'shielded',
#   'tempests',
#   'koronos',
#   'levying',
#   'unperceived',
#   'better-',
#   'forbearance',
#   'six-year',
#   'hunter-eagle',
#   'fledglings',
#   'disdain',
#   'coppice',
#   'polyxenos',
#   'crossing',
#   'calamity',
#   'searches',
#   'pandaros',
#   'deluged',
#   'hindrance',
#   'spews',
#   'fangs',
#   'well-established',
#   ...},
#  'tlg0012.tlg002.perseus-eng3.txt': {'faultless',
#   'descry',
#   'gulp',
#   'costly',
#   'porous',
#   'labours',
#   'thrinacia',
#   'females',
#   'elder.',
#   'guiding',
#   'ebbing',
#   'bow-tip',
#   'wrenched',
#   'sheep—so',
#   'whencesoever',
#   'antinous',
#   'choose.',
#   'forbear.',
#   'reply',
#   'sea-eagles',
#   'boors',
#   'lading-plank',
#   'oversee',
#   'stone.',
#   'prayer.',
#   'aeson',
#   'down.',
#   'autolycus.',
#   'prospers',
#   'ephialtes—men',
#   'trusts',
#   'thee—hounds',
#   'surround',
#   'thistle-tufts',
#   'gave.',
#   'weighted',
#   'propping',
#   'plight.',
#   'farthermost',
#   'strew',
#   'bow.',
#   'say.',
#   'arms.',
#   'clings',
#   'electrum',
#   'spellbound',
#   'tiding',
#   'sheep-gut—so',
#   'yard-arm',
#   'rags.',
#   'trial—to',
#   'ripen',
#   'it—for',
#   'instilled',
#   'gladsome',
#   'eye—',
#   'god—',
#   'refuses',
#   'phaethusa',
#   'teaching',
#   'blossomed',
#   'sayest.',
#   'spurned',
#   'growling',
#   'widespread',
#   'bedabbled',
#   'spiders',
#   'melts',
#   'warm.',
#   'purged',
#   'for.',
#   'ship-wrights',
#   'bellies—then',
#   'fruit—there',
#   'roof.',
#   'darken',
#   'rend.',
#   'spirit.',
#   'sunder',
#   'go.',
#   'owes',
#   'watched.',
#   'achilles.',
#   'times—and',
#   'dealings',
#   'mills',
#   'loneliness',
#   'earth.',
#   '—nor',
#   'sorts—whensoever',
#   'that.',
#   'revolved',
#   'wavers',
#   'robe—i',
#   'unbroken—not',
#   'befoul',
#   'gift.',
#   'thaws',
#   'me—my',
#   'eyelids—but',
#   'far-off',
#   'wickedness.',
#   'begirt',
#   'basest',
#   'heracles—his',
#   'contest.',
#   'fair—so',
#   'resort',
#   'me—be',
#   'spirit—even',
#   'dolius',
#   'greenwood',
#   'trimming',
#   'shrivelling',
#   'price.',
#   'unprovoked',
#   'wallet.',
#   'gloves',
#   'helius',
#   'woos',
#   'scornfully',
#   'oneself',
#   'hither.',
#   'onward—soon',
#   'skulks',
#   'high-of-heart',
#   'someday',
#   'apollo—for',
#   'crack-brained',
#   'stratius',
#   'dangers',
#   'sun—a',
#   'minstrels.',
#   'icmalius',
#   'well-watered',
#   'hoes',
#   'separately.',
#   'sway—young',
#   'valiance',
#   'hairy',
#   'obtain',
#   'icarius',
#   'rub',
#   'achaeans.',
#   'ignorance',
#   'shoved',
#   'well-washed',
#   'quaffs',
#   'am.',
#   'hand-washing',
#   'dome',
#   'cravens',
#   'strength.',
#   'trotted',
#   'planctae',
#   'far.',
#   'cliffs—then',
#   'monsters',
#   'us—',
#   'describest',
#   'dreams.',
#   'shadow',
#   'strengthening',
#   'drill',
#   '—fool',
#   'multitudinous',
#   'envy',
#   'elsewhere.',
#   'weds',
#   'scooped',
#   'look—as',
#   'water-grass',
#   'freight-ship',
#   'entertainment.',
#   'two-fold',
#   'piling',
#   'back-stay',
#   'fuller',
#   'trim',
#   'passer-by',
#   'mind—tell',
#   'people.',
#   'sleep.',
#   'calledst',
#   'whit—',
#   'trimmed',
#   'fateful',
#   'hades.',
#   'prize—',
#   'land—his',
#   'worse.',
#   'bathing',
#   'alcandre',
#   'aegyptus',
#   'king.',
#   'giants.',
#   'rebukes',
#   'throw.',
#   'masters—',
#   'aeaea',
#   'unmoored',
#   'vermin',
#   'ready.',
#   'eurymedusa',
#   'feast.',
#   'alcippe',
#   'fulfil',
#   'bossy',
#   'strokes',
#   'things—',
#   'maimer',
#   'upstretched',
#   'new-sawn',
#   'door-post',
#   'chafing',
#   'baffling',
#   'flock.',
#   'mockery',
#   'jewel',
#   'desires.',
#   'continuously',
#   'befits',
#   'themselves.',
#   'lede',
#   'tale.',
#   'lordliest',
#   'misty',
#   'death-struggle',
#   'far-wandering',
#   'scanned',
#   'suppliant.',
#   'crates',
#   'feels',
#   'perished.',
#   'judged',
#   'jeered',
#   'craftsmen',
#   'supreme.',
#   'couldest',
#   'undertook',
#   'swallowed',
#   'consented',
#   'assume',
#   'bountifully',
#   'thee—the',
#   'dissembler',
#   'winnowing-fan',
#   'kindness.',
#   'scrapings',
#   'vaulted-over',
#   'sore-tried',
#   'babes',
#   'cajole',
#   'athlete.',
#   'quailest',
#   'befooling',
#   'bed—bedstead',
#   'foe.',
#   'meaningless',
#   'city.',
#   'dawn.',
#   'overcast',
#   'loosened.',
#   'destruction.',
#   'curled',
#   'whistling',
#   'wife.',
#   'forever',
#   'bustle',
#   'polyneus',
#   'myself.',
#   'neaera',
#   'echetus',
#   'oughtest',
#   'fast.',
#   'harmest',
#   'irksome',
#   'freshly-washed',
#   'accompaniments',
#   'amphialus',
#   'arm.',
#   'telemachus.',
#   'wooest',
#   'marriage.',
#   'forgetting',
#   'grief—unless',
#   'cephallenians.',
#   'doors—straightway',
#   'popular',
#   'leucothea',
#   'this—having',
#   'bedims',
#   'scurf',
#   'spars',
#   'above.',
#   'feed.',
#   'empty-handed',
#   'lackest',
#   'whelp',
#   'mind.',
#   'rivals',
#   'aphrodite.',
#   'aid.',
#   'roves',
#   'unmanned',
#   'threatens',
#   'southwest',
#   'dancing-lawns',
#   'hoof',
#   'denial',
#   'devise.',
#   'helper.',
#   'challenges',
#   'warms',
#   'casts',
#   'appears.',
#   'soul-consuming',
#   'iphicles',
#   'carpentry',
#   'dastardly',
#   'thwarting',
#   'coping',
#   'oversees',
#   'owest',
#   'ladder',
#   'afterward',
#   'sheep-pen',
#   'reproach.',
#   'pinched',
#   'unharassed',
#   'spins',
#   'stuffs',
#   'heardest',
#   'named.',
#   'men—though',
#   'convoy',
#   'prevail.',
#   'sea-mew',
#   'unfalteringly',
#   'word.',
#   'befalls',
#   'true-born',
#   'halyards',
#   'markest',
#   'demoptolemus',
#   'comeliness.',
#   'of.',
#   'insolence.',
#   'depend.',
#   'assembly—for',
#   'men—meanwhile',
#   'curve',
#   'trustiest',
#   'words.',
#   'this—what',
#   'is—has',
#   'naught—ate',
#   'scorns',
#   'wizard',
#   'weeping.',
#   'eilithyia',
#   'decree',
#   'skilful',
#   'seeks',
#   'porticoes',
#   'trilling',
#   'lost.',
#   'fig-trees',
#   'dancing-floors',
#   'spinners',
#   'these.',
#   'bachelors—and',
#   'risings',
#   'hummed',
#   'random',
#   'heaven.',
#   'stalls',
#   'hand—a',
#   'thinkest',
#   'thrive',
#   'scatters',
#   'many-voiced',
#   'pelted',
#   'others.',
#   'consorting',
#   'soothingly',
#   'rust—',
#   'knaves',
#   'wroth.',
#   '—he',
#   'heritage.',
#   'many—aye',
#   'power—now',
#   'gods.',
#   'looses',
#   'talkest',
#   'escapes',
#   'pranced',
#   'bed-post',
#   'good-for-naught',
#   'lessened',
#   'stature.',
#   'roundabout',
#   'glory.',
#   'answer—verily',
#   'axes—what',
#   'lord.',
#   'unawakening',
#   'spoil.',
#   'troublous',
#   'bleated',
#   'released',
#   'costliest',
#   'troubled.',
#   'quicken',
#   'frets',
#   'together—even',
#   'itylus',
#   'boon—honor',
#   'persephone—',
#   'bones.',
#   'outworn.',
#   'powerless',
#   'variance',
#   'weaves',
#   'moving',
#   'out-stripped',
#   'statelier',
#   'constrain',
#   'eye.',
#   'acroneus',
#   'brutal',
#   'resolve',
#   'comprehend',
#   'threateningly',
#   'response',
#   'eurymachus',
#   'long-shanked',
#   'consortest',
#   'sulphurous',
#   '—secretly',
#   'die.',
#   'abase',
#   'well.',
#   'pitied.',
#   'produces',
#   'taphians.',
#   'oh',
#   'overhears',
#   'theoclymenus',
#   'trade',
#   'polycaste',
#   'doorposts',
#   'besets',
#   'phaeacians.',
#   'shadows.',
#   'dishes',
#   'folly.',
#   'boards',
#   'pelasgians',
#   'gifts.',
#   'crackled',
#   'wheedling',
#   'substance.',
#   'oedipodes',
#   'wafted',
#   'takest',
#   'over-full',
#   'zacynthus—and',
#   'last.',
#   'knewest',
#   'alcmaeon',
#   'grief.',
#   'day.',
#   'oarsmen—that',
#   'binds',
#   'sight.',
#   'iron—even',
#   'stunted',
#   'finely',
#   'scraped',
#   'home-coming',
#   'unfailing',
#   'compassion.',
#   'unprofitably',
#   'beget',
#   'melantheus',
#   'knowledge.',
#   'paced',
#   'cavern—all',
#   'bores',
#   'awry',
#   'forebode',
#   'purging',
#   'reputed',
#   'roof-beam',
#   'withal.',
#   'mothers—so',
#   'fellow.',
#   'nericus',
#   'crown—of',
#   'perils.',
#   'designed',
#   'fawningly',
#   'honourest',
#   'torment',
#   'earth—two',
#   'crataiis',
#   'gaea',
#   'secret.',
#   'cross-planks',
#   'suspect.',
#   'wares',
#   'fitteth',
#   'townsmen',
#   'charybids',
#   'ortilochus',
#   'question.',
#   'banqueters',
#   'doorway.',
#   'winking',
#   'bootes',
#   'longs',
#   'unrighteousness',
#   'escape.',
#   'rekindled',
#   'debating',
#   'bewailed',
#   'hut.',
#   'eurylochus',
#   'another—',
#   'wouldest.',
#   'drifting',
#   'taphos',
#   'bridles',
#   'oar-loving',
#   'fair-wrought',
#   'acastus',
#   'cuttlefish',
#   'was—to',
#   'oarblades',
#   'ruin.',
#   'perishes',
#   'hollows',
#   '—thy',
#   'well-seasoned',
#   'anoints',
#   'inextricable',
#   'sires',
#   'repute',
#   'thee.',
#   'maidens.',
#   'phemius',
#   'much.',
#   'decent',
#   'armour.',
#   'implements',
#   'father—again',
#   'cup.',
#   'weeps.',
#   'rich.',
#   'restraint',
#   'shrill-blowing',
#   'trace.',
#   'wooers.',
#   'unravelling',
#   'hiding-places',
#   'cities.',
#   'sea-ward',
#   'envelops',
#   'alector',
#   'overseer',
#   'thralls',
#   'paeeon',
#   'creeps',
#   'things—who',
#   'lawlessness—ctesippus',
#   'yardarm',
#   'cureless',
#   'hand.',
#   'stronger.',
#   'foot.',
#   'consort',
#   'fives',
#   'coming.',
#   'revel',
#   'fulfil.',
#   'trunk',
#   'far—to',
#   'pass.',
#   'pondering—things',
#   'float',
#   'in.',
#   'drowse',
#   'achieves',
#   'distressed.',
#   'strangers—zeus',
#   'feet.',
#   'greathearted',
#   'too.',
#   'home—that',
#   "would'st",
#   'churls',
#   'blessed.',
#   'aegis.',
#   'spirals',
#   'strowing',
#   'long-oared',
#   'richer',
#   'conspicuous',
#   'enquired',
#   'mouldering',
#   'leucas',
#   'fan',
#   'barter',
#   'treacherous',
#   'waiting-woman',
#   'maidservants',
#   'deep.',
#   'flask',
#   'full.',
#   'apollo.',
#   'oared',
#   'me—there',
#   'plentiful',
#   'friends.',
#   'nectar.',
#   'roaming',
#   'sorceress',
#   'chins',
#   'noble.',
#   'remedy—the',
#   'wed.',
#   'awaking',
#   'mantius',
#   'faint.',
#   'wind.',
#   'valor.',
#   'man—why',
#   'store.',
#   'himself.',
#   'marrowy',
#   'trojans.',
#   'possessions.',
#   'zeus.',
#   'confusedly.',
#   'shews',
#   'colts',
#   'cyllenian',
#   'greets',
#   'strong-blowing',
#   'remembers',
#   'kindred',
#   'nameless',
#   'rehearsed',
#   'fringed',
#   'vanish',
#   'twigs',
#   'twinklings',
#   'unhonored',
#   'sawest',
#   'ctesius',
#   'met.',
#   'thicket-lair',
#   'woody',
#   'cloak.',
#   'prelude',
#   'gunwales',
#   'passes',
#   'hurt.',
#   'simple-minded',
#   'long-leafed',
#   'sorrows.',
#   'side—even',
#   'touches',
#   'prospect',
#   'force.',
#   'earned',
#   'brace',
#   'yelping',
#   'practised',
#   'explored',
#   'shepherded',
#   'warrior.',
#   'fallen.',
#   'requital.',
#   'be.',
#   'thine.',
#   'arises',
#   'evening.',
#   'lodge',
#   'across—and',
#   'unversed',
#   'sicilian',
#   'fisher',
#   'table-dogs',
#   'mid-sea',
#   'thoughts.',
#   'sunium',
#   'smear',
#   'vagabonds',
#   'irus',
#   'need.',
#   'decisive',
#   'unmanned.',
#   'gifted',
#   'aegisthus',
#   'sicilians',
#   'evade',
#   'submittest',
#   'supping',
#   'ctimene',
#   'nudging',
#   'gold.',
#   'pear-trees',
#   'deigned',
#   'shoulder.',
#   'ocyalus',
#   'gone.',
#   '3',
#   'frown',
#   'gulps',
#   'pleasure—',
#   'night.',
#   'withal—that',
#   'begrudge',
#   'cavernous',
#   'comest',
#   'jet',
#   'loosens',
#   'tarriest',
#   'one—for',
#   'live.',
#   'wakens',
#   'sooth.',
#   'willow',
#   'abound.',
#   'scour',
#   'carven',
#   'amnisus',
#   'reared.',
#   'amphinomus',
#   'life.',
#   'saves',
#   'today',
#   'tellest',
#   'upholding',
#   'ploughlands',
#   'provoked',
#   'two-and-twenty',
#   'ferrymen',
#   'fittingly',
#   'blame.',
#   'unrestrained',
#   'geraestus',
#   'balm',
#   'ogygia',
#   'unmilked',
#   'was—',
#   'kitchen-wife',
#   'gad-fly',
#   'high-horned',
#   'blows.',
#   'swirl',
#   'crouni',
#   'enquiry',
#   'newest',
#   'soiled—there',
#   'a-flutter',
#   'graciously',
#   'footsteps.',
#   'longed-for',
#   'self-taught',
#   'vagabond.',
#   'wreckers',
#   'away.',
#   'wide-spread',
#   'livest',
#   'osiers',
#   'unravel',
#   'spider-webs.',
#   'weaned',
#   'laughable',
#   'fore-stays',
#   'road-steads',
#   'close-barred',
#   'finely-wrought',
#   'melanthius.',
#   'chasm',
#   'sorrow—',
#   'deceiving.',
#   'conquers',
#   'scratches',
#   'beguiles',
#   'planks',
#   'naught—a',
#   'leiocritus',
#   'guidance',
#   'shame.',
#   'kings—one',
#   'thee—hail',
#   'weaving—',
#   'women—',
#   'no-wise',
#   'lament—yet',
#   'feud',
#   'tender-heartedness',
#   'twirl',
#   'travailing',
#   'steering-oar',
#   'return.',
#   'thrice-ploughed',
#   'endured.',
#   'epeus',
#   'alone.',
#   'come.',
#   'passers-by',
#   'yet—our',
#   'obey.',
#   'line—',
#   'neion',
#   'fiery-pointed',
#   'hireling',
#   'nurture',
#   'newly-washed',
#   'nuisance',
#   'postern',
#   'tilted',
#   'establish',
#   'land—a',
#   'tapering',
#   'house—proud',
#   'tityos',
#   'violet-dark',
#   'belched',
#   'seemlier',
#   'lower—they',
#   'throughly',
#   'atonement.',
#   'enjoyest',
#   'perished—as',
#   'all—one',
#   'deep-lowing',
#   'stranger—i',
#   'wine-grape',
#   'afar.',
#   'rejoicing.',
#   'assurance',
#   '—in',
#   'lamus',
#   'mirth',
#   'besides.',
#   'fair-faced',
#   'gathers',
#   'rite',
#   'turning-places',
#   'best.',
#   'true-hearted',
#   'tame',
#   'athena.',
#   'warrant',
#   'stablish',
#   'deigns',
#   'stout-hoofed',
#   'visitest',
#   'roamed',
#   'pictures',
#   'galling',
#   'amazed',
#   'unwinged',
#   'archer-god',
#   'mournfully',
#   'pursuit.',
#   'me—for',
#   'core',
#   'eurynomus',
#   'shrinkest',
#   'arnaeus',
#   'somewhat.',
#   'robe—',
#   'close-fitting',
#   'seawater',
#   'naught—so',
#   'thou.',
#   'indeed.',
#   'forsake',
#   'cake',
#   'criest',
#   'chanced',
#   'hazarding',
#   'them—he',
#   'dimmed',
#   'seagirt',
#   'feebleness',
#   'slunk',
#   'god.',
#   'welter',
#   'pontonous',
#   'sword-hilt',
#   'keeper',
#   'heritage',
#   'ctesippus',
#   'forests.',
#   'mocked',
#   'wailings',
#   'erembi',
#   'acheans',
#   'halls.',
#   'disquiet',
#   'bright-throned',
#   'juniper',
#   'mending',
#   'trot',
#   'woman—amazement',
#   'harm.',
#   'ample',
#   'sand-spits',
#   'refusest',
#   'islands—dulichium',
#   'piloting',
#   'stairway',
#   'forboded',
#   'together.',
#   'un-irused',
#   'morticings',
#   'behove',
#   'desiring',
#   'males—the',
#   'oftenest',
#   'anticlus',
#   'wanders',
#   '—grievous',
#   'unchanged',
#   'fates.',
#   'bloodshed.',
#   'strength—and',
#   'honours',
#   'was.',
#   'adventure',
#   'furling',
#   'swamp-land',
#   'lacks',
#   'anabesineus',
#   'vessels—',
#   'telemachus—for',
#   'well-wooded',
#   'falcons',
#   'raiment.',
#   'guiltless.',
#   'steering',
#   'pools',
#   'wooers—fools',
#   'gleams',
#   'unheeding',
#   'seams',
#   'bade—though',
#   'cheerless',
#   'boars.',
#   'prompts',
#   'craved',
#   'bethinks',
#   'trenches',
#   'made.',
#   'enquiring',
#   '—how',
#   'time.',
#   'rainy',
#   'pays',
#   'acts',
#   'mate',
#   'booming',
#   'launching',
#   'bewitch',
#   'meal.',
#   'unseemly.',
#   'flaxen',
#   'circe.',
#   'impious',
#   'head-gear',
#   'merchantman',
#   'gainful',
#   'mishandling',
#   'unseemly—but',
#   'slave-women',
#   'fair-stablished',
#   'four-fold',
#   'blooming',
#   'lends',
#   'anticleia',
#   'guardest',
#   'telepylus',
#   'contriving',
#   'settlement',
#   'gulfs',
#   'well-fatted',
#   'sing.',
#   'beaters',
#   'sweet-smelling',
#   'notes',
#   'persisting',
#   ...}}

# %% [markdown]
# ## Your turn
#
# Now that you've seen the basics of TF-IDF, use the `set`s that we've built to explore the values for several terms in this corpus.
#
# As you explore, make note of any findings that seem odd — are they errors in how we have run the analysis, or is the text just weird?
#
# Consider, too, how you might improve the analysis in the future.
#
# Then in your own words, describe _what_ TF-IDF is really telling us about a given term in each text and within the corpus as a whole.
#
# Finally, think about other objects of study for which TF-IDF might be useful.

# %%
terms_to_explore = ["odysseus", "achilles", "trojan", "homer", "war"]

for term in terms_to_explore:
    print(f"Occurrences of '{term}' across documents:")

    for filename, values in tokenized_texts.items():
        count = values['counts'].get(term, 0)
        print(f"  {filename}: {count} times")

    print()
# Out:
# Occurrences of 'odysseus' across documents:
#   tlg0012.tlg001.perseus-eng3.txt: 128 times
#   tlg0012.tlg002.perseus-eng4.txt: 580 times
#   tlg0012.tlg001.perseus-eng4.txt: 124 times
#   tlg0012.tlg002.perseus-eng3.txt: 635 times
#
# Occurrences of 'achilles' across documents:
#   tlg0012.tlg001.perseus-eng3.txt: 410 times
#   tlg0012.tlg002.perseus-eng4.txt: 17 times
#   tlg0012.tlg001.perseus-eng4.txt: 422 times
#   tlg0012.tlg002.perseus-eng3.txt: 16 times
#
# Occurrences of 'trojan' across documents:
#   tlg0012.tlg001.perseus-eng3.txt: 21 times
#   tlg0012.tlg002.perseus-eng4.txt: 7 times
#   tlg0012.tlg001.perseus-eng4.txt: 67 times
#   tlg0012.tlg002.perseus-eng3.txt: 2 times
#
# Occurrences of 'homer' across documents:
#   tlg0012.tlg001.perseus-eng3.txt: 0 times
#   tlg0012.tlg002.perseus-eng4.txt: 0 times
#   tlg0012.tlg001.perseus-eng4.txt: 0 times
#   tlg0012.tlg002.perseus-eng3.txt: 0 times
#
# Occurrences of 'war' across documents:
#   tlg0012.tlg001.perseus-eng3.txt: 224 times
#   tlg0012.tlg002.perseus-eng4.txt: 13 times
#   tlg0012.tlg001.perseus-eng4.txt: 68 times
#   tlg0012.tlg002.perseus-eng3.txt: 27 times

# %% [markdown]
# "trojan" appears infrequently. It’s much less common than expected in tlg002 - this could be due to variations in translation or because of plurality; "trojans" instead of "trojan."
#
# You could improve the analysis by ensuring that words like "trojan" vs. "trojans" are counted properly; in this case, they might be counted separately, leading to varied results.
#
# Within each text, a high TF-IDF means a word is important to that document, which is why "odysseus" has high TF-IDF in tlg002 but low TF-IDF in tlg001. Across the corpus, words appearing in every document, like "war," have lower IDF, making them less informative.
